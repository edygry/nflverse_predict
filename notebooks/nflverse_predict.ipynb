# %%
import nfl_data_py as nfl
start = 2022
end = 2023
years = range(start, end+1, 1)
# pbp_data=nfl.import_pbp_data(years, downcast=True, cache=False, alt_path=None)
# pbp_data['index_col'] = pbp_data.index
# pbp_data=pbp_data.copy()
seasonal_data = nfl.import_seasonal_data(years)
# seasonal_data['index_col'] = seasonal_data.index
# seasonal_data=seasonal_data.copy()
#weekly_data = nfl.import_weekly_data(years, downcast=True)
#weekly_rosters = nfl.import_weekly_rosters(years)
#win_totals = nfl.import_win_totals(years)
# seasonal_roster = nfl.import_seasonal_rosters(years)

# seasonal_roster['index_col'] = seasonal_roster.index
# seasonal_roster=seasonal_roster.copy()
# ngs_data = nfl.import_ngs_data('kicking',years)
# depth_chart = nfl.import_depth_charts(years)
# depth_chart['index_col'] = depth_chart.index
# depth_chart['gsis_it_id'] = depth_chart['gsis_id'].apply(lambda x: x.replace('00-00',''))
#injuries = nfl.import_injuries(years)
# injuries['index_col'] = injuries.index  

ftn_data = nfl.import_ftn_data(years)
# ftn_data['index_col'] = ftn_data.index

# player_id_cols = [x.split('player_id')[0] for x in nfl.see_pbp_cols() if x.endswith('player_id')]



#push test - pablo
# Out:
# Downcasting floats.

# %%
import pandas as pd
dfs = pd.read_html('https://www.nfl.com/stats/team-stats/special-teams/field-goals/2024/reg/all')
stat_df = dfs[0]

# %%
import featuretools as ft
dataframes = {
    "pbp_data": (pbp_data,'index','game_date'),
    "seasonal_data": (seasonal_data,'index'),
    "seasonal_roster": (seasonal_roster,'index'),   
    # "depth_chart": (depth_chart,'index_col'),
    "injuries": (injuries,'index'),
    "ftn_data": (ftn_data,'index'),
}
relationships = [
    ("pbp_data", "player_id", "seasonal_data", "player_id"),
    ("pbp_data", "player_id", "seasonal_roster", "player_id"),
    # ("pbp_data", "player_id", "depth_chart", "player_id"),
    ("pbp_data", "player_id", "injuries", "player_id"),
    ("pbp_data", "play_id", "ftn_data", "nflverse_play_id"),
    ("pbp_data", "game_id", "ftn_data", "nflverse_game_id"),
    
]

feature_matrix_pbp, feature_defs = ft.dfs(
    dataframes=dataframes,
    relationships=relationships,
    target_dataframe_name="pbp_data",
)
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/featuretools/entityset/entityset.py:1733: UserWarning: index index not found in dataframe, creating new integer column
#   warnings.warn(
# /home/vscode/.local/lib/python3.11/site-packages/featuretools/entityset/entityset.py:1746: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(0, index, range(len(df)))
# /home/vscode/.local/lib/python3.11/site-packages/woodwork/type_sys/utils.py:33: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(
# ...
